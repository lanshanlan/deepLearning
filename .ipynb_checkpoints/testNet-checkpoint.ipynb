# %%
from utils.loadData import load_data_fashion_mnist

# batch_size = 64
# train_iter = load_data_fashion_mnist(batch_size=batch_size)
# for X, y in train_iter:
#     print(X.shape, X.dtype, y.shape, y.dtype)
#     break

train_iter, test_iter = load_data_fashion_mnist(batch_size=256)
for X, y in train_iter:
    print(X.shape, X.dtype, y.shape, y.dtype)
    break
# Out:
# len1(mnist_train)=60000, len(mnist_test)=10000
# torch.Size([64, 1, 28, 28]) torch.float32 torch.Size([64]) torch.int64
